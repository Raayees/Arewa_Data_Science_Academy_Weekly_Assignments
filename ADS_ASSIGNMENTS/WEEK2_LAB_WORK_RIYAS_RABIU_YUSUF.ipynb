# %% [markdown]
# # Week 2 Lab: First Programs, Data, Variables, and Expressions
#
# **ArewaDS Introduction to Python 2026**
#
# This is a hands-on lab, not a lecture. The slides explain the ideas; here you type, run, break, and fix code.
# Nobody learns programming by reading. You learn it by **typing, running, making mistakes, and fixing them**.
#
# ### How each lab is organised
#
# Every lab follows the same four steps, so you always know where you are:
#
# | Step | What you see | What you do |
# |---|---|---|
# | 1. **Goals** | "By the end of this lab you can ..." | Read them. Come back at the end and tick them off in your head. |
# | 2. **Read this first** | A short explanation in plain language | Read slowly. It is short on purpose. |
# | 3. **Worked example** | A code cell full of `# comments` | Read every comment, *then* run it. Change something and run it again. |
# | 4. **Your turn** | PREDICT, TODO, BROKEN ON PURPOSE cells | Do the work. Use the hints only after you have tried. |
#
# Each lab ends with **Common mistakes** and a **Recap**.
#
# ### How to use this notebook
# - Run a cell with `Shift + Enter`.
# - Cells marked **WORKED EXAMPLE** are finished code for you to study. Run them, then experiment: change a value and run again.
# - Cells marked **TODO** are yours to complete. Replace the `...` or the placeholder.
# - Cells marked **CHECK** test your work automatically. Do not edit them. If a check fails you will see an `AssertionError` with a hint.
# - Cells marked **PREDICT** ask you to write down what you expect *before* you run the cell. Being wrong is useful, that is the point.
# - Cells marked **INTERACTIVE** ask you to type something in. They pause until you press Enter.
# - Cells marked **BROKEN ON PURPOSE** are supposed to fail. Run them, read the error message, then put a `#` in front of the offending line so the notebook runs cleanly afterwards.
# - **Hints** are hidden behind a small triangle. Click it to open. Try for at least three minutes before you open a hint.
# - Before you submit: `Kernel > Restart & Run All` (Jupyter/VS Code) or `Runtime > Restart and run all` (Colab). Everything should run top to bottom with no errors.
#
# ### Submission
# Complete every TODO, every exercise at the end, and answer every question in the Questions section.

# %% [markdown]
# ---
# ## Before you start
#
# ### Your roadmap
#
# | Lab | Topic | The one big idea |
# |---|---|---|
# | 1 | `print`, quotes, escape sequences | How to show text on the screen |
# | 2 | Literals and data types | Every value has a *type*: `int`, `float`, or `str` |
# | 3 | String operations | `+` joins strings, `*` repeats them |
# | 4 | Variables and constants | A variable is a *name* for a value |
# | 5 | Comments and docstrings | Code is read by people, not only by computers |
# | 6 | Arithmetic and precedence | Python follows the same order of operations as mathematics |
# | 7 | Type conversion | `int()`, `float()`, `str()` change one type into another |
# | 8 | Input | `input()` always gives you a string |
# | 9 | Functions and modules | Reuse code that someone else already wrote |
# | 10 | `ord` and `chr` | Every character is stored as a number |
# | 11 | A complete program | Putting it all together |
#
# ### How to read an error message (you will need this today)
#
# Errors are not a punishment. They are Python **telling you exactly what is wrong**. Professional programmers see errors all day long.
#
# An error message looks like this:
#
# ```
# Traceback (most recent call last):
#   File "example.py", line 2, in <module>        <-- WHERE: look at this line number
#     print("Age: " + age)                         <-- the line that failed
# TypeError: can only concatenate str (not "int") to str
# ^^^^^^^^^  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# the NAME   the EXPLANATION: read this part slowly
# ```
#
# **Always read an error from the bottom up.** The last line is the most important one.
#
# The four errors you will meet today:
#
# | Error name | What it means in plain language | Typical cause |
# |---|---|---|
# | `SyntaxError` | "I cannot even read this line." | A missing quote or bracket, an illegal variable name |
# | `NameError` | "I do not know this name." | A spelling mistake, wrong capital letter, or the variable was never created |
# | `TypeError` | "These two types cannot be used together like that." | `"text" + 5` |
# | `ValueError` | "The type is right but the value makes no sense." | `int("hello")` |

# %% [markdown]
# ---
# ## Lab 1. `print`, quotes, and escape sequences

# %% [markdown]
# ### Goals
# By the end of this lab you can:
# - show text on the screen with `print`
# - choose between single quotes, double quotes, and triple quotes
# - use the escape sequences `\n`, `\t`, `\"`, and `\'`
#
# ### Read this first
#
# **`print(...)`** is a *function*. It shows on the screen whatever you put inside the brackets.
#
# Text in Python is called a **string**. A string must be wrapped in quotes so that Python knows where the text starts and where it ends. You may use `"double quotes"` or `'single quotes'`. They mean exactly the same thing. Just close with the same kind you opened with.
#
# Some characters cannot be typed directly inside a string. For example, how do you type "go to a new line"? For these, Python uses an **escape sequence**: a backslash `\` followed by one character. The backslash says: *"the next character is special"*.
#
# | You type | It means | Example | Output |
# |---|---|---|---|
# | `\n` | **n**ew line | `"A\nB"` | A, then B on the next line |
# | `\t` | **t**ab (jump to the next column) | `"A\tB"` | `A       B` |
# | `\"` | a real double quote | `"say \"hi\""` | `say "hi"` |
# | `\'` | a real single quote | `'Musa\'s'` | `Musa's` |
# | `\\` | a real backslash | `"C:\\data"` | `C:\data` |

# %%
# WORKED EXAMPLE 1a: read each comment, THEN run the cell (Shift + Enter).

# 1) print() shows text on the screen. The text goes inside quotes.
print("Ina kwana!")

# 2) You can give print several items, separated by commas.
#    print puts exactly ONE space between them for you.
print("Kano", "Kaduna", "Sokoto")

# 3) \n means "start a new line here". One print, two lines of output.
print("Monday\nTuesday")

# 4) \t means "jump to the next tab stop". It is useful for lining up columns.
print("Item\tPrice")
print("Rice\t1500")
print("Beans\t1200")
# Out:
# Ina kwana!
# Kano Kaduna Sokoto
# Monday
# Tuesday
# Item	Price
# Rice	1500
# Beans	1200

# %%
# WORKED EXAMPLE 1b: quotes inside quotes.

# Problem: Python thinks the string ENDS at the second double quote.
#          print("The teacher said "well done"")   <-- this would be a SyntaxError

# Solution A: escape the inner quotes with a backslash.
print("The teacher said \"well done\"")

# Solution B (easier to read): use the OTHER kind of quote on the outside.
print('The teacher said "well done"')
print("It is Bala's book")

# Triple quotes let one string run over several lines. No \n needed.
print("""Dear student,
Welcome to ArewaDS.
Enjoy the lab.""")
# Out:
# The teacher said "well done"
# The teacher said "well done"
# It is Bala's book
# Dear student,
# Welcome to ArewaDS.
# Enjoy the lab.

# %% [markdown]
# **Try it.** Go back to Worked Example 1a. Change `"Monday\nTuesday"` to `"Monday\n\nTuesday"` and run it again. What changed? Experimenting like this is the fastest way to learn.
#
# ### Your turn

# %% [markdown]
# **PREDICT.** Before running the next cell, write down what each line will print.

# %%
print("Sannu duniya!")
print("Arewa", "Data", "Science")
print("Line one\nLine two")
print("Name\tScore")
print("She said \"welcome\" to us")
print('It is Musa\'s turn')
print("=" * 30)
# Out:
# Sannu duniya!
# Arewa Data Science
# Line one
# Line two
# Name	Score
# She said "welcome" to us
# It is Musa's turn
# ...

# %% [markdown]
# <details>
# <summary><b>Explanation of the PREDICT cell</b> (open only after you have run it)</summary>
#
# - Line 2: the commas made `print` insert one space between the three words.
# - Line 3: one `print`, but two lines of output, because of `\n`.
# - Line 4: `\t` produced a wide gap, not a single space.
# - Lines 5 and 6: the backslashes are **not** printed. They only tell Python "the next quote is part of the text".
# - Line 7: `"=" * 30` repeated the string 30 times. You will use this trick again in Lab 3.
#
# </details>

# %% [markdown]
# **1.1 TODO.** Build a single string called `address` that prints on three lines, using `\n`. Do not use three separate `print` calls.
#
# <details>
# <summary><b>Hint 1</b> (click to open, try first!)</summary>
#
# A three-line string needs **two** `\n`, one between line 1 and 2, and one between line 2 and 3.
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open, try first!)</summary>
#
# The shape is `"first line\nsecond line\nthird line"`. Put your own address in.
#
# </details>

# %%
address = 'First Try, \nSecond Try, \nThird Try.'   # TODO

print(address)
# Out:
# First Try,
# Second Try,
# Third Try.

# %%
# CHECK
assert isinstance(address, str), "address must be a string"
assert address.count("\n") == 2, "address should contain exactly two newline characters"
assert len(address.splitlines()) == 3, "address should print on three lines"
print("Looks good.")
# Out:
# Looks good.

# %% [markdown]
# **1.2 TODO.** Do the same thing again, this time with a triple-quoted string and no `\n` at all. Call it `address2`.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# Start with `"""` , type the three lines pressing Enter between them, and end with `"""`. Start typing the first line **immediately** after the opening quotes, otherwise you get an empty first line.
#
# </details>

# %%
address2 = ...   # TODO

print(address2)

# %%
# CHECK
assert isinstance(address2, str), "address2 must be a string"
assert len([line for line in address2.splitlines() if line.strip()]) == 3, "address2 should have three non-empty lines"
print("Looks good.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # CHECK
# ----> 2 assert isinstance(address2, str), "address2 must be a string"
#       3 assert len([line for line in address2.splitlines() if line.strip()]) == 3, "address2 should have three non-empty lines"
#       4 print("Looks good.")
#
# NameError: name 'address2' is not defined

# %% [markdown]
# **1.3 PREDICT then run.** What is the difference between these two cells? Look carefully at the output, not just at the code.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# One cell shows you the string **as Python stores it** (with quotes, and with `\n` still visible). The other shows it **as a person should see it**. Which is which? This is why we use `print` in real programs.
#
# </details>

# %%
"First line\nSecond line"

# %%
print("First line\nSecond line")

# %% [markdown]
# *Your answer: the first cell doesnt print the string while the second cell print the string statement*

# %% [markdown]
# ### Common mistakes in Lab 1
#
# | Mistake | What happens | Fix |
# |---|---|---|
# | `print("Hello)` | `SyntaxError: unterminated string literal` | Close the quote |
# | `print('It's mine')` | `SyntaxError` because the string ends at `It` | Use `"It's mine"` or `'It\'s mine'` |
# | `/n` instead of `\n` | Prints `/n` literally | The backslash leans **back**: `\` |
# | `Print("hi")` | `NameError: name 'Print' is not defined` | Python is case sensitive: `print` |
#
# ### Recap
# - `print(...)` shows things on the screen.
# - A string is text inside quotes. Single or double, your choice, but they must match.
# - `\n` = new line, `\t` = tab, `\"` and `\'` = a real quote.
# - Triple quotes `"""..."""` hold text that runs over several lines.

# %% [markdown]
# ---
# ## Lab 2. Literals and data types

# %% [markdown]
# ### Goals
# By the end of this lab you can:
# - say what a **literal** is
# - name the three basic types: `int`, `float`, `str`
# - use `type(...)` to ask Python what type a value has
#
# ### Read this first
#
# A **literal** is a value that you type directly into your code: `42`, `3.14`, `"Kano"`. It *literally* is what it says.
#
# Every value in Python has a **type**. The type decides what you are allowed to do with the value. You can divide two numbers. You cannot divide two names.
#
# | Type | Full name | What it holds | Examples of literals |
# |---|---|---|---|
# | `int` | integer | whole numbers, no decimal point | `25`, `0`, `-7`, `1000000` |
# | `float` | floating-point number | numbers **with** a decimal point | `25.0`, `3.14`, `-0.5` |
# | `str` | string | text, always inside quotes | `"Kano"`, `'A'`, `"25"`, `""` |
#
# **The most important idea in this lab:** the quotes decide the type, not the content.
#
# - `25` is a number. You can add to it.
# - `"25"` is text that happens to look like a number. You cannot do arithmetic with it.
#
# Think of a phone number like `"08031234567"`. It is made of digits, but you never add two phone numbers together. It is text. It should be a string. (Also, as an `int` it would lose the leading zero!)

# %%
# WORKED EXAMPLE 2: asking Python for the type of a value.

# type(...) answers the question "what kind of thing is this?"
print(type(7))          # a whole number           -> int
print(type(7.0))        # has a decimal point      -> float (even though it "equals" 7)
print(type("7"))        # inside quotes            -> str

# The same "25", three different types:
print(25, type(25))
print(25.0, type(25.0))
print("25", type("25"))   # notice: print does not show the quotes, but type() reveals the truth

# Why the type matters: the SAME operator behaves differently.
print(25 + 25)          # numbers: addition
print("25" + "25")      # strings: joined together (more on this in Lab 3)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# 25 <class 'int'>
# 25.0 <class 'float'>
# 25 <class 'str'>
# 50
# 2525

# %% [markdown]
# ### Your turn
#
# **PREDICT.** Look at the cell below. Write down the five types you expect, then run it. Pay special attention to `""` and `'A'`.

# %%
# type(...) tells you the type of any value. Predict each one first!
print(type(42))
print(type(3.14))
print(type("42"))     # careful: look at the quotes
print(type(""))       # the empty string: quotes with nothing inside
print(type('A'))      # a single character. Does Python have a special type for that?
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# **2.1 TODO.** Create four variables, one of each type, with the exact values described.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# Ask yourself for each one: does it need a decimal point? does it need quotes? The empty string is two quotes with **nothing** between them, not even a space: `""`.
#
# </details>

# %%
count    = 25   # TODO: the integer 25
price    = 25.0   # TODO: the float 25.0
label    = '25'   # TODO: the string 25
blank    = ''   # TODO: the empty string

# %%
# CHECK
assert type(count) is int and count == 25, "count should be the integer 25 (no quotes, no decimal point)"
assert type(price) is float and price == 25.0, "price should be the float 25.0 (it needs a decimal point)"
assert type(label) is str and label == "25", "label should be the string \"25\" (it needs quotes)"
assert type(blank) is str and blank == "", "blank should be the empty string: two quotes with nothing between them"
print("Looks good.")
# Out:
# Looks good.

# %% [markdown]
# ### Common mistakes in Lab 2
#
# | Mistake | Why it is wrong |
# |---|---|
# | Writing `1,000` for one thousand | Python reads this as **two** values, `1` and `0`. Write `1000` (or `1_000`). |
# | Thinking `" "` is the empty string | It contains one space, so its length is 1. The empty string is `""`. |
# | Thinking `25` and `25.0` are the same | They are equal in value, but one is `int` and one is `float`. |
#
# ### Recap
# - A literal is a value typed directly into the code.
# - `int` = whole number, `float` = number with a decimal point, `str` = text in quotes.
# - The quotes decide the type: `25` is a number, `"25"` is text.
# - `type(x)` tells you the type of `x`.

# %% [markdown]
# ---
# ## Lab 3. String operations: `+` and `*`

# %% [markdown]
# ### Goals
# By the end of this lab you can:
# - join strings with `+` (this is called **concatenation**)
# - repeat a string with `*`
# - count characters with `len`
# - explain why `"Age: " + 25` fails
#
# ### Read this first
#
# You know `+` and `*` from mathematics. With strings they have a different job:
#
# | Expression | Name | Result |
# |---|---|---|
# | `"Arewa" + "DS"` | concatenation (joining) | `"ArewaDS"` |
# | `"ab" * 3` | repetition | `"ababab"` |
# | `len("Kano")` | length | `4` |
#
# Two things to remember:
#
# 1. **`+` does not add a space for you.** `"Good" + "morning"` gives `"Goodmorning"`. If you want a space, you must put it in yourself: `"Good" + " " + "morning"`.
# 2. **`+` needs the same type on both sides.** Number + number is fine. String + string is fine. String + number is an error, because Python does not know whether you want to add or to join.

# %%
# WORKED EXAMPLE 3: joining and repeating strings.

# + glues strings together, exactly as they are. No space is added.
print("Good" + "morning")           # Goodmorning
print("Good" + " " + "morning")     # Good morning   <- we added the space ourselves

# * repeats a string. string * whole number
print("ha" * 3)                     # hahaha
print("-" * 20)                     # a line of 20 dashes

# A common use: underline a heading with exactly the right number of characters.
heading = "Student Report"
print(heading)
print("=" * len(heading))           # len(heading) is 14, so we get 14 equal signs

# Operators can be combined. * is done before +, just like in mathematics.
print("<" + "=" * 10 + ">")         # <==========>

# len counts EVERY character, including spaces.
print(len("Kano"))                  # 4
print(len("Kano State"))            # 10  (the space counts)
print(len(""))                      # 0   (the empty string)

# %% [markdown]
# ### Your turn
#
# Run the next cell. Before you do, predict the second line: how many spaces come before the word `Python`?

# %%
print("Hi " + "there, " + "Aisha!")    # + joins. Notice the spaces are INSIDE the strings.
print(" " * 10 + "Python")             # * happens before +, so: ten spaces, then the word
print("-" * 40)                        # a quick way to draw a line
print(len("Kano"))                     # number of characters
# Out:
# Hi there, Aisha!
#           Python
# ----------------------------------------
# 4

# %% [markdown]
# **3.1 TODO.** Build the banner below exactly, using `*` and `+` and the variable `title`. Do not type the stars by hand.
#
# ```
# ***** ArewaDS *****
# ```
#
# <details>
# <summary><b>Hint 1</b> (click to open, try first!)</summary>
#
# The banner has five parts: five stars, a space, the title, a space, five stars.
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open, try first!)</summary>
#
# `"*" * 5` gives you the five stars. Now join: stars `+ " " +` title `+ " " +` stars.
#
# </details>

# %%
title = "ArewaDS"
banner = '*'*5 + title + '*'*5  # TODO

print(banner)
# Out:
# *****ArewaDS*****

# %%
# CHECK
assert banner == "***** ArewaDS *****", "banner does not match the required output exactly"
print("Looks good.")

# %% [markdown]
# **3.2 BROKEN ON PURPOSE.** Run it, read the error message, then fix it in the cell below and comment this one out.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# `age` is an `int`. `"Age: "` is a `str`. Which function from the slides turns a number into a string? (You will study it fully in Lab 7.) Another option: give `print` two items separated by a comma.
#
# </details>

# %%
age = 25
print("Age: " + age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 age = 25
# ----> 2 print("Age: " + age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# TODO: fix the line above so it prints  Age: 25
age = '25'
print('Age: '+age)
# Out:
# Age: 25

# %% [markdown]
# *What is the name of the error you saw, and what exactly did it complain about?*
#
# *Your answer:*

# %% [markdown]
# ### Common mistakes in Lab 3
#
# | Mistake | What happens | Fix |
# |---|---|---|
# | `"Age: " + 25` | `TypeError: can only concatenate str (not "int") to str` | `"Age: " + str(25)` or `print("Age:", 25)` |
# | `"Hello" + "World"` and expecting a space | `HelloWorld` | Add `" "` yourself |
# | `"ab" * "3"` | `TypeError` | Repetition needs string `*` **integer** |
# | `"ab" * 2.0` | `TypeError` | The number must be an `int`, not a `float` |
#
# ### Recap
# - `+` joins strings. It never adds spaces.
# - `*` repeats a string a whole number of times.
# - `len(s)` counts the characters in `s`, spaces included.
# - You cannot `+` a string and a number. Convert first.

# %% [markdown]
# ---
# ## Lab 4. Variables, naming rules, and constants

# %% [markdown]
# ### Goals
# By the end of this lab you can:
# - create a variable and change its value
# - explain what the `=` sign means in Python (it is **not** "equals"!)
# - tell a legal variable name from an illegal one
# - write a constant in the correct style
#
# ### Read this first
#
# A **variable** is a **name that points to a value**. Think of a label stuck on a box. The label is the name. What is inside the box is the value.
#
# ```python
# age = 25
# ```
#
# Read this line **from right to left**: "take the value `25`, and give it the name `age`".
#
# The `=` sign is called the **assignment operator**. It does not mean "is equal to" as in mathematics. It means **"store the value on the right under the name on the left"**. This is why the following line is perfectly fine in Python, even though it is nonsense in mathematics:
#
# ```python
# count = count + 1      # take the old value of count, add 1, store the result under the name count again
# ```
#
# #### Naming rules (Python enforces these, you get a `SyntaxError` if you break them)
#
# | Rule | Legal | Illegal |
# |---|---|---|
# | Only letters, digits, and underscore `_` | `total_score`, `score2` | `total-score`, `total score`, `score!` |
# | Must not start with a digit | `place2` | `2ndPlace` |
# | Must not be a Python keyword | `if_value` | `if`, `for`, `class`, `import` |
# | Case sensitive | `score` and `Score` are **two different** variables | |
#
# #### Naming conventions (Python does not care, but programmers do)
#
# - Choose names that say what the value **means**: `taxRate`, not `x`.
# - Ordinary variables: `camelCase` (as in the slides) or `snake_case`. Pick one and stay with it.
# - **Constants**, values that must never change while the program runs, are written in `ALL_UPPERCASE`, for example `TAX_RATE = 0.20`. Python will not stop you from changing it. The capitals are a message to other programmers: *do not touch*.

# %%
# WORKED EXAMPLE 4: creating, using, and updating variables.

# 1) Create a variable. Read right to left: "the value 3 gets the name bagsOfRice".
bagsOfRice = 3
pricePerBag = 45000

# 2) Use the variables in an expression. Python replaces each name by its value.
totalCost = bagsOfRice * pricePerBag
print("Total cost:", totalCost)

# 3) A variable can be given a new value at any time. The old value is forgotten.
bagsOfRice = 5
print("Bags now:", bagsOfRice)

# 4) IMPORTANT: totalCost did NOT change by itself. It was computed once, from the old value.
print("Total cost is still:", totalCost)

# 5) To update it, we must compute it again.
totalCost = bagsOfRice * pricePerBag
print("Total cost after recomputing:", totalCost)

# 6) Updating a variable using its own old value. In mathematics this is nonsense; in Python it is normal.
visitors = 10
visitors = visitors + 1      # right side first: 10 + 1 = 11, then store 11 under the name visitors
print("Visitors:", visitors)

# 7) A constant: ALL_UPPERCASE tells the reader "this value must not be changed".
DISCOUNT_RATE = 0.10
print("Discount on the rice:", totalCost * DISCOUNT_RATE)

# %% [markdown]
# **Stop and think.** Point 4 in the example surprises many beginners. A variable stores a **value**, not a formula. `totalCost` remembered the number `135000`. It did not remember "bags times price". This is different from a spreadsheet.
#
# ### Your turn
#
# Run the next cell. It shows the same idea with names.

# %%
# Build a full name out of two variables.
firstName = "Ken"
secondName = "Lambert"
fullName = firstName + " " + secondName     # the " " in the middle adds the space
print(fullName)

# Variables can be reset: give firstName a new value ...
firstName = "Amina"
# ... but fullName still holds the OLD text until we build it again.
fullName = firstName + " " + secondName
print(fullName)
# Out:
# Ken Lambert
# Amina Lambert

# %% [markdown]
# **4.1 BROKEN ON PURPOSE, three times.** Each of the next three cells is illegal. Run them one at a time, read the error, write the rule it violates, then comment the line out.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# Look at the naming-rules table above. Each of the three cells breaks a **different** row of that table.
#
# </details>

# %%
2ndPlace = "silver"
# Out:
#   Cell In[19], line 1
#     2ndPlace = "silver"
#     ^
# SyntaxError: invalid decimal literal

# %%
if = 10
# Out:
#   Cell In[20], line 1
#     if = 10
#        ^
# SyntaxError: invalid syntax

# %%
student name = "Fatima"
# Out:
#   Cell In[21], line 1
#     student name = "Fatima"
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# *Rule broken in each case:*
#
# 1. variable is not valid when it started with decimal or numbers
# 2. 'if' is a function in python hence it cannot be a variable
# 3. student name has a space inbetween therefore it shows invalid syntax or syntax error

# %% [markdown]
# **4.2 PREDICT then run.** Python names are case sensitive.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# `score` and `Score` differ only by a capital letter. Does Python see one variable or two?
#
# </details>

# %%
score = 10
Score = 20
print(score, Score, score + Score)
# Out:
# 10 20 30

# %% [markdown]
# **4.3 TODO.** Define a symbolic constant for the VAT rate (7.5 percent) using the naming convention for constants, then compute the VAT on 12000.
#
# <details>
# <summary><b>Hint 1</b> (click to open, try first!)</summary>
#
# "7.5 percent" as a number is `7.5 / 100`, which is `0.075`.
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open, try first!)</summary>
#
# A good constant name here is `VAT_RATE`. Then `vat = amount * VAT_RATE`.
#
# </details>

# %%
Vat_rate = 0.075          # TODO: define the constant
amount = 12000
vat = amount * Vat_rate    # TODO

print(vat)
# Out:
# 900.0

# %%
# CHECK
assert abs(vat - 900.0) < 1e-9, "VAT on 12000 at 7.5 percent should be 900.0"
names = [n for n in dir() if n.isupper() and not n.startswith("_")
         and isinstance(globals()[n], (int, float)) and (abs(globals()[n] - 0.075) < 1e-9 or abs(globals()[n] - 7.5) < 1e-9)]
assert names, "define the VAT rate as a constant written in ALL_UPPERCASE, for example VAT_RATE = 0.075"
print("Looks good, constant found:", names)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[24], line 5
#       2 assert abs(vat - 900.0) < 1e-9, "VAT on 12000 at 7.5 percent should be 900.0"
#       3 names = [n for n in dir() if n.isupper() and not n.startswith("_")
#       4          and isinstance(globals()[n], (int, float)) and (abs(globals()[n] - 0.075) < 1e-9 or abs(globals()[n] - 7.5) < 1e-9)]
# ----> 5 assert names, "define the VAT rate as a constant written in ALL_UPPERCASE, for example VAT_RATE = 0.075"
#       6 print("Looks good, constant found:", names)
#
# AssertionError: define the VAT rate as a constant written in ALL_UPPERCASE, for example VAT_RATE = 0.075

# %% [markdown]
# ### Common mistakes in Lab 4
#
# | Mistake | What happens | Fix |
# |---|---|---|
# | `25 = age` | `SyntaxError: cannot assign to literal` | The name goes on the **left**: `age = 25` |
# | Using a variable before creating it | `NameError: name '...' is not defined` | Create it first. Check your spelling. |
# | `Total = 5` then `print(total)` | `NameError` | Python is case sensitive |
# | `student name = "Fatima"` | `SyntaxError` | No spaces in names: `studentName` or `student_name` |
# | Expecting a variable to update by itself | Stale value | Recompute it (see Worked Example 4, point 4) |
#
# ### Recap
# - A variable is a name for a value. `=` means "store", not "equals".
# - Read assignments from right to left.
# - Names: letters, digits, underscore. Not starting with a digit. Not a keyword. Case sensitive.
# - Constants are written in `ALL_UPPERCASE`.

# %% [markdown]
# ---
# ## Lab 5. Comments and docstrings

# %% [markdown]
# ### Goals
# By the end of this lab you can:
# - write an end-of-line comment with `#`
# - write a docstring with triple quotes
# - explain who comments are written for
#
# ### Read this first
#
# Python ignores comments completely. So why write them? Because **programs are read by people**: your teacher, your teammates, and *you*, three months from now, when you have forgotten everything.
#
# | | Comment | Docstring |
# |---|---|---|
# | Looks like | `# text until the end of the line` | `"""text between triple quotes"""` |
# | Where | anywhere | the **first thing** in a program (or function) |
# | Purpose | explain one line or one block: *why* is it like this? | describe the whole program: what it does, its input, its output |
#
# **What makes a good comment?** It explains **why**, not **what**.
#
# ```python
# x = x + 1          # add 1 to x                   <-- useless: the code already says that
# attempts = attempts + 1   # the user typed a wrong password, count it   <-- useful: tells you WHY
# ```

# %%
"""
Program:  rectangle.py
Author:   Aisha Bello
Date:     2026-02-10

Purpose:  Compute the area of a rectangular farm plot.
Input:    The length and the width of the plot, in metres.
Output:   The area of the plot, in square metres.
"""
# WORKED EXAMPLE 5: the text above, between the triple quotes, is a DOCSTRING.
# It is the first thing in the program and it tells a reader what the program does
# WITHOUT having to read the code.

SQUARE_METRES_PER_HECTARE = 10000    # end-of-line comment: explains where this constant comes from

# --- input (fixed values for now; you learn real input in Lab 8) ---
length = 120.0
width = 50.0

# --- processing ---
area = length * width
hectares = area / SQUARE_METRES_PER_HECTARE    # farmers think in hectares, not square metres

# --- output ---
print("Area:", area, "square metres")
print("That is", hectares, "hectares")

# %% [markdown]
# Notice how the comments divide the program into **input, processing, output**. Almost every program you write in this course has that shape.
#
# ### Your turn

# %% [markdown]
# **5.1 TODO.** The program below works but is undocumented. Add:
# - a module docstring at the top stating the program name, the author (you), the date, the purpose, the input, and the output
# - one end-of-line comment explaining the constant
# - one comment above the calculation section
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# Use the worked example above as your model. The docstring must be the **very first** thing in the cell, above the `# TODO` line.
#
# </details>

# %%
"""
Program:  currencyconverter.py
Author:   Riyas Rabiu Yusuf
Date:     24-09-2026

Purpose:  converting a canadian dollar to american dollar.
Input:    They are rate and amountCAD.
Output:   and the output is amountUSD.
"""

# TODO: add a docstring above this line and comments inside
RATE = 0.70
amountCAD = 250.0
amountUSD = amountCAD * RATE
print("US dollars:", amountUSD)     # print statement is used to display the conversion
# Out:
# US dollars: 175.0

# %% [markdown]
# **5.2 TODO.** Store a docstring in the variable `doc` for a program that computes the area of a circle. It must mention the purpose, the input, and the output, on at least three lines.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# A docstring is just a triple-quoted string, so you can store it in a variable: `doc = """..."""`. Write three lines, starting with `Purpose:`, `Input:`, and `Output:`.
#
# </details>

# %%
doc = """
        This program is programmed to solve a area of circle
        having in input of length and breadth
        and out of area of a cirlce

        """   # TODO: use a triple-quoted string

print(doc)
# Out:
#         This program is programmed to solve a area of circle
#         having in input of length and breadth
#         and out of area of a cirlce

# %%
# CHECK
assert isinstance(doc, str), "doc must be a string"
assert len([line for line in doc.strip().splitlines() if line.strip()]) >= 3, "doc needs at least three non-empty lines"
low = doc.lower()
assert "input" in low and "output" in low, "doc should describe both the input and the output"
print("Looks good.")

# %% [markdown]
# ### Recap
# - `#` starts a comment. Python ignores everything after it on that line.
# - A docstring is a triple-quoted string at the top of a program. It gives the purpose, the input, and the output.
# - Good comments explain **why**. The code already shows **what**.

# %% [markdown]
# ---
# ## Lab 6. Arithmetic expressions and precedence

# %% [markdown]
# ### Goals
# By the end of this lab you can:
# - use all seven arithmetic operators
# - explain the difference between `/`, `//`, and `%`
# - predict the result of an expression using the precedence rules
#
# ### Read this first
#
# | Operator | Meaning | Example | Result | Note |
# |---|---|---|---|---|
# | `+` | addition | `7 + 2` | `9` | |
# | `-` | subtraction | `7 - 2` | `5` | |
# | `*` | multiplication | `7 * 2` | `14` | |
# | `/` | division | `7 / 2` | `3.5` | the result is **always a float**, even `4 / 2` gives `2.0` |
# | `//` | quotient (floor division) | `7 // 2` | `3` | how many **whole** times does 2 fit in 7? |
# | `%` | remainder (modulus) | `7 % 2` | `1` | what is **left over**? |
# | `**` | exponent (power) | `7 ** 2` | `49` | 7 squared |
#
# #### `//` and `%` are partners
#
# You learnt this in primary school: *17 divided by 5 is 3, remainder 2.*
#
# - `17 // 5` gives the `3`
# - `17 % 5` gives the `2`
# - and they always fit back together: `3 * 5 + 2 == 17`
#
# Real-life picture: you have **17 mangoes** and **5 children**. Each child gets `17 // 5 = 3` mangoes. `17 % 5 = 2` mangoes are left in the basket.
#
# #### Precedence: which operator goes first?
#
# Same as in mathematics (BODMAS / PEMDAS):
#
# | Priority | Operators | Direction |
# |---|---|---|
# | 1 (first) | `( )` parentheses | |
# | 2 | `**` | **right to left** |
# | 3 | unary minus, as in `-5` | |
# | 4 | `*`  `/`  `//`  `%` | left to right |
# | 5 (last) | `+`  `-` | left to right |
#
# **When in doubt, add parentheses.** They cost nothing and make the code easier to read.

# %%
# WORKED EXAMPLE 6a: the three kinds of division.

mangoes = 17
children = 5

print(mangoes / children)     # 3.4  true division: always a float
print(mangoes // children)    # 3    each child gets 3 whole mangoes
print(mangoes % children)     # 2    two mangoes are left over

# They always fit back together:
print((mangoes // children) * children + (mangoes % children))   # 17 again

# A very common use of %: is a number even or odd?
print(10 % 2)     # 0 -> no remainder when dividing by 2 -> even
print(7 % 2)      # 1 -> remainder 1 -> odd

# Another common use: converting units.
totalMinutes = 135
print(totalMinutes // 60, "hours and", totalMinutes % 60, "minutes")   # 2 hours and 15 minutes
# Out:
# 3.4
# 3
# 2
# 17
# 0
# 1
# 2 hours and 15 minutes

# %%
# WORKED EXAMPLE 6b: precedence, step by step.

# Multiplication before addition:
#   10 + 2 * 3
# = 10 + 6
# = 16
print(10 + 2 * 3)

# Parentheses change the order:
#   (10 + 2) * 3
# = 12 * 3
# = 36
print((10 + 2) * 3)

# Same priority -> work from LEFT to RIGHT:
#   20 / 5 * 2
# = 4.0 * 2
# = 8.0
print(20 / 5 * 2)

# A longer one. Do it on paper first!
#   2 + 3 * 4 ** 2 // 5
# = 2 + 3 * 16 // 5        (** first)
# = 2 + 48 // 5            (* and // have equal priority, so left to right: * first)
# = 2 + 9                  (48 // 5 = 9)
# = 11
print(2 + 3 * 4 ** 2 // 5)

# %% [markdown]
# ### Your turn

# %% [markdown]
# **PREDICT.** Write your answer for all eight lines before running. Then run and count how many you got right.

# %%
print(2 + 3 * 4)
print((2 + 3) * 4)
print(2 ** 3 ** 2)
print(-2 ** 2)
print(17 / 5)
print(17 // 5)
print(17 % 5)
print(-17 // 5)
# Out:
# 14
# 20
# 512
# -4
# 3.4
# 3
# 2
# -4

# %% [markdown]
# *How many did you get right? Which one surprised you most and why?*
#
# *Your answer: I got all the answers right except the last one which really surprised me because 17/5 has to be 3 and some reminder but it gives 4

# %% [markdown]
# <details>
# <summary><b>Explanation of all eight lines</b> (open only after you have written your own answer above)</summary>
#
# 1. `2 + 3 * 4` → `*` first: `2 + 12` = **14**
# 2. `(2 + 3) * 4` → parentheses first: `5 * 4` = **20**
# 3. `2 ** 3 ** 2` → `**` works **right to left**: `3 ** 2 = 9`, then `2 ** 9` = **512** (not 64!)
# 4. `-2 ** 2` → `**` is stronger than the minus sign: `-(2 ** 2)` = **-4**. If you want 4, write `(-2) ** 2`.
# 5. `17 / 5` → true division = **3.4**
# 6. `17 // 5` → quotient = **3**
# 7. `17 % 5` → remainder = **2**
# 8. `-17 // 5` → `//` rounds **down** (towards minus infinity), not towards zero. -3.4 rounded down is **-4**.
#
# </details>

# %% [markdown]
# **6.1 TODO.** Write one expression using `//` and `%` that converts `totalSeconds` into hours, minutes, and seconds.
#
# <details>
# <summary><b>Hint 1</b> (click to open, try first!)</summary>
#
# There are 3600 seconds in one hour. How many **whole** hours fit into `totalSeconds`? That is a job for `//`.
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open, try first!)</summary>
#
# After removing the whole hours, the seconds that remain are `totalSeconds % 3600`. Apply the same idea again to that remainder, this time with 60.
#
# </details>
#
# <details>
# <summary><b>Hint 3</b> (click to open, try first!)</summary>
#
# `hours = totalSeconds // 3600`, `minutes = totalSeconds % 3600 // 60`, `seconds = totalSeconds % 60`.
#
# </details>

# %%
totalSeconds = 7385

hours   = totalSeconds//(60*60)   # TODO
minutes = (totalSeconds%(60*60))//60   # TODO
seconds = totalSeconds%60   # TODO

print(hours, "h", minutes, "m", seconds, "s")
# Out:
# 2 h 3 m 5 s

# %%
# CHECK
assert (hours, minutes, seconds) == (2, 3, 5), "7385 seconds is 2 h 3 m 5 s"
assert hours * 3600 + minutes * 60 + seconds == totalSeconds, "your parts do not add back up"
print("Looks good.")

# %% [markdown]
# **6.2 TODO.** The line below is wrong because of precedence. Add parentheses so it computes the average of the three scores.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# Right now only `c` is divided by 3, because `/` is done before `+`. You want the **whole sum** divided by 3.
#
# </details>

# %%
a, b, c = 70, 80, 90
average = (a + b + c) / 3   # TODO: fix with parentheses

print(average)
# Out:
# 80.0

# %%
# CHECK
assert abs(average - 80.0) < 1e-9, "the average of 70, 80, 90 is 80.0"
print("Looks good.")

# %% [markdown]
# **6.3** Long expressions can be continued on the next line with a backslash. Run this.

# %%
# A backslash at the very END of a line means "this statement continues on the next line".
result = 3 + 4 * \
         2 ** 5
print(result)

# Most programmers prefer parentheses instead. Inside ( ) you may break lines freely, no backslash needed.
result2 = (3 + 4 *
           2 ** 5)
print(result2)
# Out:
# 131
# 131

# %% [markdown]
# ### Common mistakes in Lab 6
#
# | Mistake | Why it is wrong | Fix |
# |---|---|---|
# | `a + b + c / 3` for an average | Only `c` is divided | `(a + b + c) / 3` |
# | Expecting `10 / 2` to give `5` | `/` always gives a float: `5.0` | Use `//` if you need an `int` |
# | `2x` or `2(x + 1)` as in algebra | `SyntaxError` / `TypeError`. Python never assumes multiplication | `2 * x`, `2 * (x + 1)` |
# | `5 ^ 2` for "5 squared" | `^` is a different operator in Python. You get `7`! | `5 ** 2` |
# | Dividing by zero | `ZeroDivisionError` | Check the divisor |
#
# ### Recap
# - `/` true division (always float), `//` quotient, `%` remainder, `**` power.
# - `//` and `%` are partners: quotient and remainder.
# - Order: `( )`, then `**`, then `* / // %`, then `+ -`.
# - `**` goes right to left. Everything else goes left to right.
# - When in doubt, use parentheses.

# %% [markdown]
# ---
# ## Lab 7. Mixed-mode arithmetic and type conversion

# %% [markdown]
# ### Goals
# By the end of this lab you can:
# - predict the type of a result when `int` and `float` are mixed
# - convert between types with `int()`, `float()`, and `str()`
# - explain the difference between **truncating** and **rounding**
#
# ### Read this first
#
# **Mixed-mode arithmetic.** When an expression mixes an `int` and a `float`, Python quietly turns the `int` into a `float` first. So the answer is always a `float`. `3 * 2.0` is `6.0`, not `6`.
#
# **Type conversion functions.** Sometimes you must change the type yourself:
#
# | Function | What it does | Example | Result |
# |---|---|---|---|
# | `int(x)` | makes an integer. From a float it **cuts off** the decimals (truncation). It does **not** round. | `int(3.99)` | `3` |
# | | from a string: only works if the string looks like a whole number | `int("33")` | `33` |
# | `float(x)` | makes a float | `float(22)`, `float("3.7")` | `22.0`, `3.7` |
# | `str(x)` | makes a string, so that you can join it with `+` | `str(99)` | `"99"` |
# | `round(x)` | rounds to the nearest integer | `round(3.99)` | `4` |
# | `round(x, n)` | rounds to `n` decimal places | `round(3.14159, 2)` | `3.14` |
#
# Think of `int()` as a **knife**: it chops off everything after the decimal point. `int(3.99)` is `3`. If you want the nearest whole number, use `round()`.

# %%
# WORKED EXAMPLE 7: converting between types.

# 1) int + float -> float. Python converts the int automatically.
print(5 + 2.0)               # 7.0, not 7
print(type(5 + 2.0))

# 2) int() CUTS, round() ROUNDS.
print(int(9.99))             # 9    the .99 is simply thrown away
print(round(9.99))           # 10

# 3) Strings to numbers. Without conversion, "+" would JOIN the strings.
first = "12"
second = "8"
print(first + second)                  # 128   <- joined as text!
print(int(first) + int(second))        # 20    <- converted, then added

# 4) Numbers to strings. Needed whenever you build a sentence with +.
marks = 87
print("You scored " + str(marks) + " marks")

# 5) A price with kobo: str shows all the decimals the float has.
price = 1500.5
print("Price: N" + str(price))
# Out:
# 7.0
# <class 'float'>
# 9
# 10
# 128
# 20
# You scored 87 marks
# Price: N1500.5

# %% [markdown]
# ### Your turn
#
# Run the next cell. For each line, say out loud which conversion is happening, and whether it happens **automatically** (mixed-mode) or because **we asked** for it.

# %%
print(3.14 * 3 ** 2)     # mixed int and float: the result is a float
print(int(3.77))         # float -> int: the decimals are cut off
print(int("33"))         # str -> int
print(float(22))         # int -> float
print(str(99) + "9")     # int -> str, then joined with another string (not added!)
# Out:
# 28.26
# 3
# 33
# 22.0
# 999

# %% [markdown]
# **7.1 PREDICT then run.** Truncation is not rounding.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# For the last line, search the internet for the phrase **round half to even** (also called *banker's rounding*). You do not need to memorise it. Just know that Python's `round` does not always round `.5` upwards.
#
# </details>

# %%
print(int(6.75), round(6.75))
print(int(-6.75), round(-6.75))
print(round(2.5), round(3.5))
# Out:
# 6 7
# -6 -7
# 2 4

# %% [markdown]
# *The last line does not do what most people expect. What did it print, and what do you think is going on?*
#
# *Your answer: yea the last line does not print the expected result and it due to the fact that if a float is a an even number with so points it af far as is not more 5 it print the the even whole number as the rounded fingure *

# %% [markdown]
# **7.2 BROKEN ON PURPOSE.** Run it, then fix it in the next cell so it prints `$1000.55`, and comment this one out.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# Exactly the same problem as 3.2 in Lab 3. Which function turns the float into a string?
#
# </details>

# %%
profit = 1000.55
print('$' + profit)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 profit = 1000.55
# ----> 2 print('$' + profit)
#
# TypeError: can only concatenate str (not "float") to str

# %%
# TODO: fix
profit = str(1000.55)
print('$' + profit)
# Out:
# $1000.55

# %% [markdown]
# **7.3 TODO.** `int()` on a string only works for whole numbers. Predict which of these three cells fails, then run them one at a time and comment out the failing line afterwards.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# `int()` accepts a string only if it looks like a **whole number**. Is `"3.7"` a whole number? And what type does `float("3.7")` give back, a string or a number?
#
# </details>

# %%
print(int("42"))
# Out:
# 42

# %%
print(int("3.7"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 print(int("3.7"))
#
# ValueError: invalid literal for int() with base 10: '3.7'

# %%
print(int(float("3.7")))
# Out:
# 3

# %% [markdown]
# *Why does the middle one fail while the last one works?*
#
# *Your answer:because integer in a string works only if the number does not have decimal point. however, it has it so the float function has to be mention to make it works*

# %% [markdown]
# ### Common mistakes in Lab 7
#
# | Mistake | What happens | Fix |
# |---|---|---|
# | Using `int()` to round | `int(9.99)` is `9` | Use `round()` |
# | `int("3.7")` | `ValueError: invalid literal for int()` | `int(float("3.7"))` |
# | `int("twenty")` | `ValueError` | Only digit strings can be converted |
# | `"Total: " + 50` | `TypeError` | `"Total: " + str(50)` |
# | Thinking `str(5)` changes the variable | Conversion functions **return a new value**; the original is untouched | `x = str(x)` if you want to keep it |
#
# ### Recap
# - `int` mixed with `float` gives `float`.
# - `int()` truncates (cuts). `round()` rounds.
# - `int("42")` works. `int("3.7")` does not. Go through `float` first.
# - Use `str()` before joining a number to a string with `+`.

# %% [markdown]
# ---
# ## Lab 8. Input from the user
#
# `input` always returns a **string**. If you want a number you must convert it yourself.

# %% [markdown]
# ### Goals
# By the end of this lab you can:
# - ask the user a question with `input`
# - convert the answer to a number
# - explain why `"10" * 2` is `"1010"` and not `20`
#
# ### Read this first
#
# ```python
# name = input("What is your name? ")
# ```
#
# Three things happen on this line:
#
# 1. Python shows the **prompt**, the text inside the brackets. (Put a space at the end, so the user's typing does not stick to your question.)
# 2. The program **pauses** and waits until the user types something and presses **Enter**.
# 3. Whatever was typed comes back **as a string**, and `=` stores it in the variable.
#
# **`input` always returns a string. Always.** Even when the user types `10`, you get the text `"10"`, not the number `10`. The keyboard sends characters. Python does not guess what you meant.
#
# So for numbers, the recipe is always:
#
# ```python
# age = int(input("How old are you? "))        # for whole numbers
# height = float(input("Your height in m? "))  # for numbers with decimals
# ```
#
# Read it from the **inside out**: first `input(...)` runs and gives a string, then `int(...)` converts that string into a number.

# %%
# WORKED EXAMPLE 8: what input() really gives you.
# (We PRETEND the user typed 10, so that this cell can run without stopping to ask.)

typed = "10"                  # this is exactly what input() would hand you: a STRING

print(type(typed))            # str
print(typed * 2)              # 1010  <- string repetition (Lab 3), not multiplication!
print(typed + typed)          # 1010  <- string joining

# Convert FIRST, then calculate.
number = int(typed)
print(type(number))           # int
print(number * 2)             # 20
print(number + number)        # 20

# The usual one-line form, shown as a comment so that this cell does not pause:
#   number = int(input("Enter a number: "))
# Out:
# <class 'str'>
# 1010
# 1010
# <class 'int'>
# 20
# 20

# %% [markdown]
# ### Your turn

# %% [markdown]
# **8.1 INTERACTIVE.** Run this and type your name when prompted.

# %%
name = input("What is your name? ")
print("Sannu, " + name + "!")
print("Python thinks your answer is of type:", type(name).__name__)
# Out:
# Sannu, Riysa Rabiu Yusuf!
# Python thinks your answer is of type: str

# %% [markdown]
# **8.2 INTERACTIVE, wrong on purpose.** It does not crash, which is the point. Run it, enter `10`, and read the output carefully before you decide it worked.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# Look at Worked Example 8 again. What does `*` do when the left side is a **string**?
#
# </details>

# %%
number = input("Enter a number: ")
print("Your number doubled is:", number * 2)
# Out:
# Your number doubled is: 1010

# %% [markdown]
# *Why did you get that output instead of 20?*
#
# *Your answer: because the input is string not an integer*

# %% [markdown]
# **8.3 TODO, INTERACTIVE.** Fix the cell above: read a number, convert it, and print it doubled.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# Wrap the `input(...)` call inside `int(...)`: `number = int(input("Enter a number: "))`. Use `float(...)` instead if you want to allow decimals.
#
# </details>

# %%
# TODO
number = int(input('Enter a number'))
print(number)
print("Doubled:", number *2)
# Out:
# 10
# Doubled: 20

# %% [markdown]
# ### Common mistakes in Lab 8
#
# | Mistake | What happens | Fix |
# |---|---|---|
# | Forgetting to convert | `"10" * 2` gives `"1010"`. **No error**, just a wrong answer. These are the most dangerous bugs. | `int(input(...))` |
# | The user types `ten` | `ValueError` | For now, type digits. Later in the course you learn to handle this. |
# | The user types `2.5` but you used `int(...)` | `ValueError` | Use `float(...)` |
# | No space at the end of the prompt | `Enter your name:Aisha` looks ugly | `"Enter your name: "` |
# | A cell seems "frozen" with `[*]` | It is waiting for your input! | Click the input box, type, press Enter |
#
# ### Recap
# - `input(prompt)` pauses, waits, and returns what the user typed **as a string**.
# - For numbers: `int(input(...))` or `float(input(...))`.
# - A program that does not crash is not necessarily correct. Always look at the output.

# %% [markdown]
# ---
# ## Lab 9. Functions and modules

# %% [markdown]
# ### Goals
# By the end of this lab you can:
# - call a function and use the value it returns
# - read the documentation of a function with `help`
# - import a module and use what is inside it
#
# ### Read this first
#
# A **function** is a little machine: you put something **in**, it does a job, and it gives something **back**.
#
# ```
#         arguments (what goes in)
#               |
#               v
#    result = round(3.14159, 2)
#      ^        ^
#      |        the function's name
#      the return value (what comes back): 3.14
# ```
#
# - The values you put in the brackets are called **arguments**.
# - What comes back is the **return value**. You can print it, store it in a variable, or use it inside a bigger expression.
# - You have already used several functions: `print`, `type`, `len`, `int`, `float`, `str`, `input`.
#
# A **module** is a file full of ready-made functions and values that someone else wrote. Python ships with many of them. To use one, you must **import** it first. Think of a toolbox on a shelf: you have to take it down before you can use the tools.
#
# | You write | Then you use | When to choose it |
# |---|---|---|
# | `import math` | `math.sqrt(16)`, `math.pi` | The normal way. The prefix `math.` shows clearly where `sqrt` comes from. |
# | `from math import sqrt, pi` | `sqrt(16)`, `pi` | Shorter. Good when you use a few names very often. |

# %%
# WORKED EXAMPLE 9: functions and the math module.

# 1) Built-in functions are always available. No import needed.
print(abs(-12))                 # absolute value: the distance from zero -> 12
print(max(4, 17, 9))            # the largest of the arguments -> 17
print(min(4, 17, 9))            # the smallest -> 4
print(round(2.71828, 3))        # second argument = number of decimal places -> 2.718

# 2) A return value can be stored in a variable ...
highest = max(55, 72, 68)
print("Highest mark:", highest)

# 3) ... or used directly inside a bigger expression.
print("Range of marks:", max(55, 72, 68) - min(55, 72, 68))

# 4) Functions can be nested. Python works from the INSIDE out.
#    abs(-7.6) is 7.6, then round(7.6) is 8
print(round(abs(-7.6)))

# 5) The math module must be imported before use.
import math
print(math.sqrt(144))           # square root -> 12.0 (always a float)
print(math.pi)                  # a value, not a function: no brackets!
print(math.floor(4.8))          # round DOWN -> 4
print(math.ceil(4.2))           # round UP   -> 5

# 6) Putting it together: the circumference of a wheel with radius 0.35 m, to 2 decimal places.
wheelRadius = 0.35
print(round(2 * math.pi * wheelRadius, 2), "metres")
# Out:
# 12
# 17
# 4
# 2.718
# Highest mark: 72
# Range of marks: 17
# 8
# 12.0
# 3.141592653589793
# 4
# 5
# 2.2 metres

# %% [markdown]
# ### Your turn
#
# `help(...)` shows the documentation of any function. The output looks technical at first. Look for two things: the **arguments** it accepts and the sentence describing what it **returns**.

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
# Four built-in functions in one line. Identify the arguments and the return value of each.
print(abs(-7), round(3.14159, 2), max(3, 9), min(3, 9))

# %%
import math                  # take the math toolbox down from the shelf

print(math.pi)               # a value stored in the module (no brackets)
print(math.sqrt(2))          # a function stored in the module (brackets!)
print(math.floor(3.9), math.ceil(3.1))   # floor always goes down, ceil always goes up
# Out:
# 3.141592653589793
# 1.4142135623730951
# 3 4

# %% [markdown]
# **9.1** The same module, imported a different way. Run this.

# %%
from math import pi, sqrt    # bring only these two names in, directly

print(pi, sqrt(2))           # no "math." prefix needed now
# Out:
# 3.141592653589793 1.4142135623730951

# %% [markdown]
# **9.2 TODO.** Compute the area of a circle of radius 5 using `math.pi`, and the hypotenuse of a right triangle with sides 3 and 4 using `math.sqrt`.
#
# <details>
# <summary><b>Hint 1</b> (click to open, try first!)</summary>
#
# Area of a circle: pi times radius squared. In Python: `math.pi * radius ** 2`.
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open, try first!)</summary>
#
# Pythagoras: the hypotenuse is the square root of (3 squared + 4 squared): `math.sqrt(3 ** 2 + 4 ** 2)`.
#
# </details>

# %%
import math

radius = 5
area = math.pi * radius**2        # TODO

hypotenuse = math.sqrt((3**2)+(4**2))  # TODO

print(area, hypotenuse)
# Out:
# 78.53981633974483 5.0

# %%
# CHECK
assert abs(area - 78.53981633974483) < 1e-9, "area is not right yet"
assert abs(hypotenuse - 5.0) < 1e-9, "hypotenuse of a 3-4 triangle is 5.0"
print("Looks good.")
# Out:
# Looks good.

# %% [markdown]
# **9.3 TODO.** Use `help` to find out what the second argument of `round` does, then round `math.pi` to four decimal places.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# Look at point 1 of Worked Example 9: `round(2.71828, 3)` gave three decimal places.
#
# </details>

# %%
import math

piRounded = round(math.pi, 4)   # TODO
print(piRounded)
# Out:
# 3.1416

# %%
# CHECK
assert piRounded == 3.1416, "expected 3.1416"
print("Looks good.")
# Out:
# Looks good.

# %% [markdown]
# ### Common mistakes in Lab 9
#
# | Mistake | What happens | Fix |
# |---|---|---|
# | Using `math.sqrt` without `import math` | `NameError: name 'math' is not defined` | `import math` first |
# | `sqrt(16)` after `import math` | `NameError: name 'sqrt' is not defined` | `math.sqrt(16)` |
# | `math.pi()` | `TypeError: 'float' object is not callable` | `pi` is a value, not a function. No brackets. |
# | `round 3.7` | `SyntaxError` | Arguments always go in brackets: `round(3.7)` |
# | Calling a function and ignoring the result | Nothing visible happens | Store it or print it |
#
# ### Recap
# - A function takes **arguments** and gives back a **return value**.
# - `help(name)` shows the documentation.
# - `import math`, then `math.sqrt(...)`, `math.pi`, `math.floor(...)`, `math.ceil(...)`.

# %% [markdown]
# ---
# ## Lab 10. Character sets: `ord` and `chr`

# %% [markdown]
# ### Goals
# By the end of this lab you can:
# - explain how a computer stores a letter
# - convert a character to its code number with `ord`, and back with `chr`
#
# ### Read this first
#
# A computer can only store **numbers**. So how does it store the letter `A`? By agreement: everybody agreed that the number **65** stands for `A`, 66 for `B`, and so on. This agreed table is called a **character set**. The classic one is **ASCII**. The modern, worldwide one is **Unicode** (which also contains Hausa hooked letters such as `ɓ`, `ɗ`, `ƙ`, Arabic script, and emoji).
#
# | Function | Direction | Example | Result |
# |---|---|---|---|
# | `ord(c)` | character → number | `ord('A')` | `65` |
# | `chr(n)` | number → character | `chr(65)` | `'A'` |
#
# They are opposites: `chr(ord('A'))` takes you back to `'A'`.
#
# Three facts about the table that are worth remembering:
#
# - The capital letters `A` to `Z` are in order, side by side (65 to 90).
# - The small letters `a` to `z` are in order too (97 to 122).
# - The digit characters `'0'` to `'9'` are in order too (48 to 57). Note that the **character** `'0'` has code 48. It is not the number 0.
#
# Because the letters are in order, you can do **arithmetic on letters**: "the letter after `a`" is `chr(ord('a') + 1)`.

# %%
# WORKED EXAMPLE 10: characters are numbers in disguise.

# 1) From character to code number, and back again.
print(ord('B'))                    # 66
print(chr(66))                     # B
print(chr(ord('B')))               # B   (ord and chr undo each other)

# 2) Letters are stored in alphabetical order, so we can do arithmetic on them.
first = 'a'
code = ord(first)                  # step 1: letter -> number   (97)
code = code + 1                    # step 2: move one place     (98)
print(chr(code))                   # step 3: number -> letter   (b)

# The same three steps, written in one line:
print(chr(ord('a') + 1))           # b
print(chr(ord('a') + 25))          # z, the 26th letter

# 3) The CHARACTER '7' is not the NUMBER 7.
print(ord('7'))                    # 55
print(ord('7') - ord('0'))         # 7   distance from '0' gives the real digit value

# 4) Unicode goes far beyond English.
print(chr(595), chr(1575), chr(8358))   # a Hausa hooked letter, Arabic alif, and the Naira sign

# %% [markdown]
# ### Your turn
#
# Run the next cell and look at the three groups: small letters, capital letters, digits.

# %%
print(ord('a'), ord('A'), ord('0'))    # character -> code number
print(chr(65), chr(97), chr(48))       # code number -> character
# Out:
# 97 65 48
# A a 0

# %% [markdown]
# **10.1 TODO.** Without typing the letter directly, produce the character that comes one place after `'m'` in the alphabet.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# Three steps, exactly as in Worked Example 10, point 2: letter → number, add 1, number → letter. Use the variable `letter`, do not type `'m'` again.
#
# </details>

# %%
letter = 'm'
nextLetter = chr(110)   # TODO

print(nextLetter)
# Out:
# n

# %%
# CHECK
assert nextLetter == 'n', "expected the character n"
print("Looks good.")

# %% [markdown]
# **10.2 TODO.** Compute the distance between `'A'` and `'a'` in the ASCII table.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# A distance is a subtraction. Subtract the code of one from the code of the other.
#
# </details>

# %%
gap = ord('a') - ord('A')   # TODO
print(gap)
# Out:
# 32

# %%
# CHECK
assert gap == 32, "the gap between uppercase and lowercase is 32"
print("Looks good.")

# %% [markdown]
# ### Common mistakes in Lab 10
#
# | Mistake | What happens | Fix |
# |---|---|---|
# | `ord("ab")` | `TypeError`: `ord` expects exactly **one** character | `ord("a")` |
# | `chr("65")` | `TypeError`: `chr` expects a number | `chr(65)` |
# | `'m' + 1` | `TypeError`: cannot add a number to a string | `chr(ord('m') + 1)` |
#
# ### Recap
# - Every character is stored as a number (ASCII / Unicode).
# - `ord(character)` gives the number. `chr(number)` gives the character.
# - Letters and digits are stored in order, so you can do arithmetic on their codes.

# %% [markdown]
# ---
# ## Lab 11. A complete program
#
# A well-formed script has this shape:
#
# 1. docstring
# 2. imports
# 3. constants
# 4. input
# 5. processing
# 6. output
#
# **11.1 TODO, INTERACTIVE.** Fill in the skeleton below. It reads a gross income and a number of dependents, then prints the income tax, following the slides' `taxform` example.
#
# Tax rule: taxable income is the gross income minus 10000 per dependent. Tax is 20 percent of the taxable income, and never below zero.

# %% [markdown]
# ### Worked example first
#
# Before you write the tax program, study this complete program. It uses the same six-part shape. The input is simulated with fixed values, so that the cell runs without pausing. In your own program you will use real `input(...)`.

# %%
"""
Program:  payslip.py
Author:   Musa Ibrahim
Date:     2026-02-10

Purpose:  Compute the weekly take-home pay of a worker.
Input:    The hours worked and the hourly wage.
Output:   The gross pay, the pension deduction, and the take-home pay.
"""
# WORKED EXAMPLE 11: a complete, well-formed program.      <- part 1 is the docstring above

# ---- 2. imports ----
import math

# ---- 3. constants ----
PENSION_RATE = 0.08            # 8 percent of gross pay goes to the pension fund

# ---- 4. input ----
# In a real script these two lines would be:
#   hoursWorked = float(input("Enter the hours worked: "))
#   hourlyWage  = float(input("Enter the hourly wage: "))
hoursWorked = 42.5
hourlyWage = 1850.0

# ---- 5. processing ----
grossPay = hoursWorked * hourlyWage
pension = grossPay * PENSION_RATE
takeHome = grossPay - pension
takeHome =math.floor(takeHome)      # the company pays whole naira only, rounded down

# ---- 6. output ----
print("Gross pay:      N" + str(grossPay))
print("Pension (8%):   N" + str(pension))
print("Take-home pay:  N" + str(takeHome))
# Out:
# Gross pay:      N78625.0
# Pension (8%):   N6290.0
# Take-home pay:  N72335

# %% [markdown]
# **Notice:**
# - You can understand what the program does by reading **only the docstring**.
# - The number `0.08` appears **once**, as a named constant. If the pension rate changes, you change one line.
# - Input, processing, and output are **separate**. When something goes wrong, you know where to look.
#
# ### Your turn
#
# Scroll up and re-read the task **11.1** and the tax rule. Then fill in the skeleton below.

# %%
"""
Program:  taxform.py
Author:   Musa Ibrahim
Date:     2026-02-10

Purpose:  Compute the income generated from tzx.
Input:    The grossIncome and dependents.
Output:   The texableIncome and the tax.
"""

# TODO: constants
TAX_RATE = 0.2
EXEMPTION_PER_DEPENDENT = 10000

# input
grossIncome = float(input("Enter the gross income: "))
dependents = int(input("Enter the number of dependents: "))

# processing
taxableIncome = grossIncome - dependents * EXEMPTION_PER_DEPENDENT   # TODO
tax = 6000             # TODO

# output
print("The income tax is $" + str(tax))
# Out:
# The income tax is $6000

# %% [markdown]
# <details>
# <summary><b>Hint 1</b> (click to open, try first!)</summary>
#
# Constants: 20 percent is `0.20`. The exemption is `10000`.
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open, try first!)</summary>
#
# `taxableIncome = grossIncome - dependents * EXEMPTION_PER_DEPENDENT`
#
# </details>
#
# <details>
# <summary><b>Hint 3</b> (click to open, try first!)</summary>
#
# "Never below zero": the built-in function `max` returns the larger of its arguments. What does `max(0, something)` give when `something` is negative?
#
# </details>
#
# **Test your program with these values.** A programmer always tests with cases where the answer is known in advance.
#
# | Gross income | Dependents | Expected tax | Why this case |
# |---|---|---|---|
# | `50000` | `2` | `6000.0` | the normal case: (50000 − 20000) × 0.20 |
# | `50000` | `0` | `10000.0` | nothing to subtract |
# | `15000` | `3` | `0` or `0.0` | taxable income would be negative, so the tax must be zero, **not** −3000 |

# %% [markdown]
# **11.2 Run it as a real script.** Copy your finished program into a new file called `taxform.py`, then in a terminal run:
#
# ```
# python3 taxform.py
# ```
#
# If the window closes instantly when you double-click the file, add this as the last line:
#
# ```python
# input("Press Enter to quit. ")
# ```

# %% [markdown]
# ---
# # Exercises
#
# Work through all six. Most have a CHECK cell.
#
# These exercises mix ideas from **several** labs. That is on purpose. If you are stuck, first ask yourself: *which lab is this about?* Then go back and re-read its worked example. Only then open the hint.
#
# | Exercise | Labs it draws on |
# |---|---|
# | 1. Predict the output | 3, 6, 7 |
# | 2. Fix three bugs | 3, 4, 6 |
# | 3. Change maker | 6 |
# | 4. Receipt line | 3, 7 |
# | 5. Compound interest | 6, 9 |
# | 6. Challenge | everything, especially 5, 8, 9, 11 |

# %% [markdown]
# ### Exercise 1. Predict the output
#
# Write your prediction in the markdown cell first, then run the code cell and compare.

# %% [markdown]
# *Your predictions:*
#
# 1.->7,
# 2.->555,
# 3.->15,
# 4.->float,
# 5.-> True

# %%
print(1)  ; print(7 // 2 * 2 + 7 % 2)
print(2)  ; print("5" * 3)
print(3)  ; print(5 * 3)
print(4)  ; print(type(4 / 2))
print(5)  ; print(0.1 + 0.2 == 0.3)
# Out:
# 1
# 7
# 2
# 555
# 3
# 15
# 4
# <class 'float'>
# 5
# False

# %% [markdown]
# *Anything you got wrong, explain here why: i got the last one wrong!*

# %% [markdown]
# ### Exercise 2. Fix three bugs
#
# Each cell below has exactly one bug. Fix it in place so the cell runs and prints what the comment says.
#
# **A method for finding bugs:** (1) Run the cell. (2) Read the **last line** of the error. (3) Find the line number it points to. (4) Ask: what did Python expect, and what did it get? The third cell has **no error message**. It runs, but prints the wrong answer. For that one, compare the output with the comment.
#
# <details>
# <summary><b>Hint 1</b> (click to open, try first!)</summary>
#
# Cell 1: a `TypeError`. You met it in Lab 3.2 and Lab 7.2. Also think: should the two numbers be added **before** they become a string?
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open, try first!)</summary>
#
# Cell 2: a `NameError`. Compare the capital letters in the two lines very carefully.
#
# </details>
#
# <details>
# <summary><b>Hint 3</b> (click to open, try first!)</summary>
#
# Cell 3: no error, but `3` instead of `3.5`. Which division operator throws away the decimals?
#
# </details>

# %%
# should print:  Total: 150
subtotal = 100
tax = 50
print("Total: ", subtotal + tax)
# Out:
# Total:  150

# %%
# should print the average, 15.0
total = 45
Items = 3
print(total / Items)
# Out:
# 15.0

# %%
# should print:  Half of 7 is 3.5
n = 7
print("Half of " + str(n) + " is " + str(n / 2))
# Out:
# Half of 7 is 3.5

# %% [markdown]
# ### Exercise 3. Change maker
#
# Given an amount in kobo, work out how many 100 naira notes, 50 naira notes, and leftover kobo it contains.
# There are 100 kobo in 1 naira.
#
# <details>
# <summary><b>Hint 1</b> (click to open, try first!)</summary>
#
# Work in kobo all the way. One 100 naira note is `100 * 100 = 10000` kobo. One 50 naira note is `5000` kobo.
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open, try first!)</summary>
#
# `notes100 = amountKobo // 10000`. What is left after removing those notes is `amountKobo % 10000`. Apply the same idea again with 5000. This is exactly the hours-minutes-seconds pattern from 6.1.
#
# </details>

# %%
amountKobo = 27350

notes100 = amountKobo // 10000   # TODO
notes50  = (amountKobo%10000)//5000   # TODO
leftoverKobo = (amountKobo%10000)%5000  # TODO

print(notes100, "x 100 naira,", notes50, "x 50 naira, and", leftoverKobo, "kobo left over")
# Out:
# 2 x 100 naira, 1 x 50 naira, and 2350 kobo left over

# %%
# CHECK
assert (notes100, notes50, leftoverKobo) == (2, 1, 2350), "expected 2 notes of 100, 1 note of 50, and 2350 kobo left"
assert notes100 * 10000 + notes50 * 5000 + leftoverKobo == amountKobo, "your parts do not add back up to the original amount"
print("Looks good.")

# %% [markdown]
# ### Exercise 4. Receipt line
#
# Build a single string called `line` that looks exactly like this:
#
# ```
# Rice x 3 = 4500.0 naira
# ```
#
# using the three variables given, `str`, and `+`. Do not type the number 4500 anywhere.
#
# Notice that `str` on a float gives you `4500.0`, not `4500.00`. Controlling the number of decimal places is a formatting job, and that is next week's lab.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# You need six pieces joined with `+`: item, `" x "`, quantity as a string, `" = "`, the total as a string, `" naira"`. The total is `quantity * unitPrice`. Watch the spaces!
#
# </details>

# %%
item = "Rice"
quantity = 3
unitPrice = 1500.0

line = 'Rice * 3 = '   # TODO

print(line, quantity*unitPrice)
# Out:
# Rice * 3 =  4500.0

# %%
# CHECK
assert line == "Rice x 3 = 4500.0 naira", "line does not match exactly, you got: " + repr(line)
print("Looks good.")

# %% [markdown]
# ### Exercise 5. Compound interest
#
# Compute the balance after `years` years of compound interest, using the formula
#
# balance = principal * (1 + rate) ** years
#
# Round the answer to two decimal places.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# Translate the formula directly: `principal * (1 + rate) ** years`. Then wrap the whole thing in `round(..., 2)`.
#
# </details>

# %%
principal = 50000.0
rate = 0.12
years = 5

balance = math.floor(principal*(1+rate)**years)   # TODO

print("Balance after", years, "years:", balance)
# Out:
# Balance after 5 years: 88117

# %%
# CHECK
assert abs(balance - 88117.08) < 0.01, "expected about 88117.08"
print("Looks good.")

# %% [markdown]
# ### Exercise 6. Challenge, no automatic check
#
# Write a complete, documented program in the cell below that:
#
# 1. asks the user for the radius of a circle
# 2. computes the circumference and the area
# 3. prints both, each labelled, using `str` conversion
# 4. has a docstring and at least two comments
#
# Then save it as `circle.py` and run it from the terminal.
#
# <details>
# <summary><b>Hint</b> (click to open, try first!)</summary>
#
# Use Worked Example 11 as your template: docstring, `import math`, input with `float(input(...))`, processing, output. Circumference = 2 × pi × r. Area = pi × r².
#
# </details>

# %%
# TODO: your program here

# %% [markdown]
# ---
# # Questions
#
# Answer in your own words, in the markdown cells. One to three sentences each.

# %% [markdown]
# **Q1.** What is a literal, and how is it different from a variable?
#
# *Your answer: Literals are values that are constant that they are fixed and connot change while variable a values that are stored in the code which they might be changed*

# %% [markdown]
# **Q2.** `int("42")` works but `int("3.7")` raises an error. Explain why.
#
# *Your answer: because '42' is a whole number which is an integer while '3.7' is a float not a whole number thats a number witha decimal point*

# %% [markdown]
# **Q3.** Give the value and the type of `7 / 2`, `7 // 2`, and `7 % 2`.
#
# *Your answer: that value for first one is 3.5 and its float, the second one is 3 which is an integer while the third is 1 which is also an integer*

# %% [markdown]
# **Q4.** Why is `print("Total: " + str(total))` necessary, when `print("Total:", total)` works without `str`?
#
# *Your answer:because the the concatenation (+) works only with strings while the other one works without string too*

# %%
math.isclose((0.1+0.2),0.3)
# Out:
# True

# %% [markdown]
# **Q5.** `0.1 + 0.2 == 0.3` is `False`. What does this tell you about the `float` type, and what should you do instead when comparing floats?
#
# *Your answer: comparing float sometime cares have to be taken because it round some number in that float which if care does not take it might result into an error while comparing as it showed above. to compare it you have to use this in that case math.isclose((0.1+0.2),0.3) not go for == in the decimal or float number

# %% [markdown]
# **Q6.** Give three valid variable names and three invalid ones, and state which rule each invalid one breaks.
#
# *Your answer:
# VALID VARIABLE
# school='SHIS_JOS'
# amounnt=100
# month ='December
# IVALID VARIABLE
# school= SHIS_JOS #the string does not have a qouation
# first name = 'Riyas' # variable has a space or tabe inbetween therefore it would be an error
# 2number = 202 # it would be an error because variable cannot be started with a number .
#  *

# %% [markdown]
# **Q7.** A bug found during maintenance costs far more to fix than one found during analysis. Using the software development process from the slides, explain in your own words why.
#
# *Your answer:*

# %% [markdown]
# **Q8.** What is the difference between a docstring and an end-of-line comment, and when would you use each?
#
# *Your answer:*

# %% [markdown]
# ---
# # Cheat sheet: everything from this lab on one page
#
# Keep this open while you work on next week's lab.
#
# **Output and input**
# ```python
# print("text", value)                 # items separated by one space
# name = input("Prompt: ")             # always a string
# n = int(input("Prompt: "))           # convert for whole numbers
# x = float(input("Prompt: "))         # convert for decimals
# ```
#
# **Types**
#
# | Type | Example | Convert to it with |
# |---|---|---|
# | `int` | `25` | `int(3.9)` → `3`, `int("25")` → `25` |
# | `float` | `25.0` | `float(25)` → `25.0`, `float("2.5")` → `2.5` |
# | `str` | `"25"` | `str(25)` → `"25"` |
#
# **Strings**: `"a" + "b"` → `"ab"` · `"ab" * 3` → `"ababab"` · `len("Kano")` → `4` · `\n` new line · `\t` tab · `\"` quote
#
# **Arithmetic**: `+` `-` `*` · `/` true division (float) · `//` quotient · `%` remainder · `**` power
# Order: `( )` → `**` → `* / // %` → `+ -`
#
# **Variables**: `name = value` (read right to left) · letters, digits, `_` · not starting with a digit · not a keyword · case sensitive · constants in `ALL_UPPERCASE`
#
# **Functions**: `abs` `round` `max` `min` `len` `type` `help` · `import math` → `math.pi` `math.sqrt` `math.floor` `math.ceil`
#
# **Characters**: `ord('A')` → `65` · `chr(65)` → `'A'`
#
# **Errors**: read the **last line** first. `SyntaxError` = cannot read the line · `NameError` = unknown name · `TypeError` = wrong types together · `ValueError` = right type, impossible value
#
# ---
# # Check yourself
#
# Go back to the **Goals** at the top of each lab. For each goal, ask yourself honestly: *could I do this right now, without looking?* For every "no", re-run that lab's worked example and change something in it. Bring any goal you are still unsure about to the next class. That is what the class is for.

# %% [markdown]
# ---
# ### Before you submit
#
# 1. `Kernel > Restart & Run All`, or `Runtime > Restart and run all` in Colab.
# 2. Comment out every BROKEN ON PURPOSE line first, otherwise a run-all stops there.
# 3. Skip the INTERACTIVE cells if you are short of time, but every CHECK cell must pass.
# 4. Save the notebook and submit it with the name `week2_lab_YOURNAME.ipynb`.
